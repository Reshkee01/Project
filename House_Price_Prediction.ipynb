# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
import plotly.express as px
import plotly.graph_objects as go
from sklearn.linear_model import Ridge

# %%
df = pd.read_csv("C:/Users/RESHMA KEESARI/Downloads/archive (1)/Housing.csv")
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0                no             yes        2      yes        furnished
# 1                no             yes        3       no        furnished
# 2                no              no        2      yes   semi-furnished
# 3                no             yes        3      yes        furnished
# 4                no             yes        2       no        furnished
# ..              ...             ...      ...      ...              ...
# 540              no              no        2       no      unfurnished
# 541              no              no        0       no   semi-furnished
# 542              no              no        0       no      unfurnished
# 543              no              no        0       no        furnished
# 544              no              no        0       no      unfurnished
#
# [545 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
duplicates= df.duplicated().sum()
duplicates
# Out:
# 0

# %%
x_data = df['area']
y_data = df['bedrooms']
plt.scatter(x_data,y_data)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()

# %%
df['area']=le.fit_transform(df['area'])
df['bedrooms']=le.fit_transform(df['bedrooms'])
df['bathrooms']=le.fit_transform(df['bathrooms'])
df['mainroad']=le.fit_transform(df['mainroad'])
df['basement']=le.fit_transform(df['basement'])
df['parking']=le.fit_transform(df['parking'])

# %%
x= df[['area','bedrooms','bathrooms','mainroad','basement','parking']]
y= df[['price']]

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2, random_state=42)
features = df[['area','bedrooms','bathrooms','mainroad','basement','parking']]
target= df[['price']]

# %%
data_new = pd.concat([features,target], axis=1)
corr_matrix= data_new.corr()
corr_matrix
# Out:
#                area  bedrooms  bathrooms  mainroad  basement   parking  \
# area       1.000000  0.163235   0.211224  0.329097  0.060676  0.360925
# bedrooms   0.163235  1.000000   0.373930 -0.012033  0.097312  0.139270
# bathrooms  0.211224  0.373930   1.000000  0.042398  0.102106  0.177496
# mainroad   0.329097 -0.012033   0.042398  1.000000  0.044002  0.204433
# basement   0.060676  0.097312   0.102106  0.044002  1.000000  0.051497
# parking    0.360925  0.139270   0.177496  0.204433  0.051497  1.000000
# price      0.575107  0.366494   0.517545  0.296898  0.187057  0.384394
#
#               price
# area       0.575107
# bedrooms   0.366494
# bathrooms  0.517545
# mainroad   0.296898
# basement   0.187057
# parking    0.384394
# price      1.000000

# %%
plt.figure(figsize=(8,8))
sns.heatmap(corr_matrix, annot= True, cmap='viridis', fmt=".2f")
plt.title("heatmap:features v/s target")
plt.show()

# %%
model= LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred= model.predict(x_test)
model.score(x_train,y_train)
# Out:
# 0.5763925019994292

# %%
mse= mean_squared_error(y_test, y_pred)
r2= r2_score(y_test,y_pred)

# %%
print(f"mean squared error:{mse:.2f}")
print(f"R - squared:{r2:.2f}")
# Out:
# mean squared error:2498570953172.19
# R - squared:0.51

# %%
plt.scatter(y_test,y_pred)
plt.xlabel("actual prices")
plt.ylabel("predicted prices")
plt.title("Actual prices v/s Predicted prices")
plt.show()

# %%
# Define new data points for prediction
new_data = [[2555, 3, 2, 1, 0, 2]]

# Predict the prices
predicted_prices = model.predict(new_data)

# Print the results
for i, price in enumerate(predicted_prices):
    print(f"Predicted price for house {i+1}: {price}")
# Out:
# Predicted price for house 1: [29371016.47984257]
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
